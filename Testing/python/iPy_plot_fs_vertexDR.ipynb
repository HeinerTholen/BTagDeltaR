# %% [markdown]
# # First look TTbar dileptonic

# %%
import ROOT
import varial
from rootpy.plotting import Hist
from varial.wrappers import HistoWrapper

# %%
def stack_vertexDR(fs, name='VertexDR'):
    getattr(fs, name+'NoMatch').SetFillColor(ROOT.kGreen)
    getattr(fs, name+'OneMatch').SetFillColor(ROOT.kRed)
    getattr(fs, name+'TwoMatch').SetFillColor(ROOT.kBlue)
    stk = varial.operations.stack((
        HistoWrapper(getattr(fs, name+'NoMatch')),
        HistoWrapper(getattr(fs, name+'OneMatch')),
        HistoWrapper(getattr(fs, name+'TwoMatch')),
    ))
    c1 = ROOT.TCanvas()
    stk.stack.Draw("hist")
    c1.BuildLegend()
    return c1

lumi_factor = 19.7 * 245000. / 11995550. / 9. # target_lumi * xsec / n_events * BR
def apply_lumi_factor(wrp):
    for v in wrp.__dict__.values():
        if isinstance(v, ROOT.TH1):
            v.Scale(lumi_factor)

# %% [markdown]
# # inclusiveMergedVertices collection
# ### Number of reconstructed IVF vertices and vertex-DR for events with 2 IVF vertices

# %%
fs = varial.diskio.read("../fileservice/ivf_merged.info")
apply_lumi_factor(fs)
fs.NumIvfVertices
# Out:
# <ROOT.TH1D object ("NumIvfVertices_ivf_merged") at 0x430b1b0>

# %%
stack_vertexDR(fs)
# Out:
# <ROOT.TCanvas object ("c1_n3") at 0x469bd30>

# %%
print "Number events within (0, 0.5]:", fs.VertexDRTwoMatch.Integral(0, 10)
fs.VertexDRTwoMatch
# Out:
# Number events within (0, 0.5]: 75.3302729392
# <ROOT.TH1D object ("VertexDRTwoMatch_ivf_merged") at 0x464b480>

# %% [markdown]
# # inclusiveMergedVerticesFiltered collection
# ### Number of reconstructed IVF vertices and vertex-DR for events with 2 IVF vertices

# %%
fs_f = varial.diskio.read("../fileservice/ivf_merged_filt.info")
apply_lumi_factor(fs_f)
fs_f.NumIvfVertices
# Out:
# <ROOT.TH1D object ("NumIvfVertices_ivf_merged_filt") at 0x4766a40>

# %%
stack_vertexDR(fs_f)
# Out:
# <ROOT.TCanvas object ("c1_n4") at 0x4774b70>

# %% [markdown]
# # bToCharmDecayVertexMerged collection
# ### Number of reconstructed IVF vertices and vertex-DR for events with 2 IVF vertices

# %%
fs_b2c = varial.diskio.read("../fileservice/ivf_b2c_merged.info")
apply_lumi_factor(fs_b2c)
fs_b2c.NumIvfVertices
# Out:
# <ROOT.TH1D object ("NumIvfVertices_ivf_b2c_merged") at 0x4617690>

# %%
stack_vertexDR(fs_b2c)
# Out:
# <ROOT.TCanvas object ("c1_n5") at 0x46332c0>

# %%
stack_vertexDR(fs_b2c, 'DrMomentumFlightdir')
# Out:
# <ROOT.TCanvas object ("c1_n6") at 0x486c960>

# %%
print "Number events within (0, 0.5]:", fs_b2c.VertexDRTwoMatch.Integral(0, 10)
fs_b2c.VertexDRTwoMatch
# Out:
# Number events within (0, 0.5]: 86.2833393309
# <ROOT.TH1D object ("VertexDRTwoMatch_ivf_b2c_merged") at 0x47e4ef0>
